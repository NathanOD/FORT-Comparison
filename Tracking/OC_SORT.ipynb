# %% [markdown]
# # Preparation

# %%
# Clone the repo and install modules
# !git clone https://github.com/noahcao/OC_SORT
# %cd /content/OC_SORT
# !pip install -qr requirements.txt
# !python setup.py develop
# !pip install cython; pip3 install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip install cython_bbox pandas xmltodict

# %%
import torch
print('Torch device : %s' % (torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'No GPU aviable'))

# %% [markdown]
# # Download weights and videos

# %%
# Weights
# !gdown 1J9--gFlEguPJtlSGRAbh7y6N4YsXlpo1

# %%
# Weights ReId
#!wget https://github.com/JDAI-CV/fast-reid/releases/download/v0.1.1/msmt_sbs_S50.pth

# %%
# Video
# !gdown 1DpBJS19H1DEuHKHs4tsev7aOoTJ0CEt-

# %% [markdown]
# # Run BoT-SORT interference

# %%
# !python tools/demo_track.py --demo_type video -f exps/example/mot/yolox_m_mix_det.py -c YoloXm-m-c.pth --path Exter1.avi --fp16 --fuse --save_result --out_path Exter1.mp4
