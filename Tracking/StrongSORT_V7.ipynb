# %% [markdown]
# # Préparation

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov7_StrongSORT_OSNet.git
# !pip install -qr Yolov7_StrongSORT_OSNet/requirements.txt
# %cd /content/Yolov7_StrongSORT_OSNet

# %%
import torch
print('On utilise PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else ' Pas de GPU disponible'))

# %% [markdown]
# # Téléchargements

# %%
# Vidéo
import os
os.mkdir(os.path.join("/content/Yolov7_StrongSORT_OSNet","videos"))
# %cd videos
# !gdown 1MLr1UO5Ts6MOOygkPCzsSXe_ql9tZeHy
# !gdown 1Z7YRfAjGBtMPeoGEcTb4rs_nNu54ED4F
# !unzip MIRROR.zip
# !rm MIRROR.zip

# %%
# Poids
import os
os.mkdir(os.path.join("/content/Yolov7_StrongSORT_OSNet/yolov7","weights"))
# %cd /content/Yolov7_StrongSORT_OSNet/yolov7/weights
# !gdown 14B9AcqSUGsyxjtYQpKs_dJIDfwE7gunN

# %%
# Création du dossier
# %cd /content/Yolov7_StrongSORT_OSNet
import os
os.mkdir(os.path.join("/content/Yolov7_StrongSORT_OSNet","weights"))

# %% [markdown]
# # Tracking

# %%
# %cd /content/Yolov7_StrongSORT_OSNet

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/Inter1v2.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-10.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-12.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-13.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-14.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-17.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-18.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-19.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-2.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-21.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-22.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-23.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-24.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-25.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-26.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-27.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-3.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-31.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-7.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid

# %%
# !python track.py --yolo-weights '/content/Yolov7_StrongSORT_OSNet/yolov7/weights/YoloV7x-m-c.pt' --source '/content/Yolov7_StrongSORT_OSNet/videos/MW-18Mar-8.avi' --classes 0 --strong-sort-weights resnet50_msmt17.pt --save-vid
