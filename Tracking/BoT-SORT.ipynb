# %% [markdown]
# # Preparation

# %%
# Clone the repo and install modules
# !git clone https://github.com/NirAharon/BoT-SORT
# %cd /content/BoT-SORT
# !pip install -qr requirements.txt
# !pip install -q cython_bbox
# !pip install -q faiss
# !sudo apt-get install libomp-dev

# %%
import torch
print('Torch device : %s' % (torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'No GPU aviable'))

# %% [markdown]
# # Download weights and videos

# %%
# Weights
# !gdown 14B9AcqSUGsyxjtYQpKs_dJIDfwE7gunN

# %%
# Weights ReId - ImageNet + Market1501 - SBS
# https://github.com/JDAI-CV/fast-reid/blob/master/MODEL_ZOO.md
#!wget https://github.com/JDAI-CV/fast-reid/releases/download/v0.1.1/market_sbs_S50.pth
# !wget https://github.com/JDAI-CV/fast-reid/releases/download/v0.1.1/msmt_bot_R50.pth

# %%
# Vidéo
import os
os.mkdir(os.path.join("/content/BoT-SORT","videos"))
# %cd videos
# !gdown 1MLr1UO5Ts6MOOygkPCzsSXe_ql9tZeHy
# !gdown 1Z7YRfAjGBtMPeoGEcTb4rs_nNu54ED4F
# !unzip MIRROR.zip
# !rm MIRROR.zip

# %%
# Script MOT
# %cd /content/BoT-SORT
# !gdown 1fu6wuqXnbekdrOwgrLHnoC1luE3V4zOw

# %%
#!cp /content/BoT-SORT/tools/mc_demo_yolov7.py /content/BoT-SORT

# %% [markdown]
# # Run BoT-SORT interference

# %%
# %cd /content/BoT-SORT
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/Inter1v2.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-10.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-12.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-13.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-14.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-17.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-18.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-19.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-2.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-21.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-22.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-23.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-24.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-25.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-26.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-27.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-3.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-31.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-7.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth

# %%
# !python mc_demo_yolov7.py --weights YoloV7x-m-c.pt --source '/content/BoT-SORT/videos/MW-18Mar-8.avi' --img-size 640 --conf-thres 0.4 --agnostic-nms --iou-thres 0.7 --track_high_thresh 0.3 --track_low_thresh 0.05 --fuse-score --with-reid --fast-reid-weights msmt_bot_R50.pth
