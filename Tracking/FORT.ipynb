# %% [markdown]
# # Preparation

# %%
# Clone the repo and install modules
# !git clone https://github.com/BenoitFaureIMT/FORT
# %cd /content/FORT
# !pip install -qr requirements.txt

# %%
import torch
print('Torch device : %s' % (torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'No GPU aviable'))

# %% [markdown]
# # Download weights and videos

# %%
# Vidéo
import os
os.mkdir(os.path.join("/content/FORT","videos"))
# %cd videos
# !gdown 1MLr1UO5Ts6MOOygkPCzsSXe_ql9tZeHy
# !gdown 1Z7YRfAjGBtMPeoGEcTb4rs_nNu54ED4F
# !unzip MIRROR.zip
# !rm MIRROR.zip

# %%
# Poids
# %cd /content/FORT
# !gdown 14B9AcqSUGsyxjtYQpKs_dJIDfwE7gunN

# %% [markdown]
# # Run CYCLOPE interference

# %%
# !python detect.py --video '/content/FORT/videos/Inter1v2.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-10.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-12.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-13.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-14.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-17.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-18.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-19.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-2.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-21.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-22.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-23.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-24.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-25.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-26.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-27.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-3.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-31.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-7.avi' --weights 'YoloV7x-m-c.pt' --save_results

# %%
# !python detect.py --video '/content/FORT/videos/MW-18Mar-8.avi' --weights 'YoloV7x-m-c.pt' --save_results
# Out:
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# ...
